# %%
from pyspark.sql import SparkSession
import sys

# %%
spark = SparkSession.builder \
        .appName("TestSparkConnection") \
        .master(spark_master) \
        .getOrCreate()

# %%
spark

# %%
spark.stop()
